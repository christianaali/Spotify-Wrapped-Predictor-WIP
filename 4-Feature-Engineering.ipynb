# %%
import pandas as pd
from datetime import datetime
import json

# %%
df = pd.read_csv("explored_spotify_data.csv")

# %%
df.head()
# Out:
#                           ts platform  ms_played conn_country  \
# 0  2025-01-01 05:11:45+00:00      osx     158443           TT
# 1  2025-01-01 05:14:52+00:00      osx     188306           TT
# 2  2025-01-01 05:18:50+00:00      osx     177280           TT
# 3  2025-01-01 05:22:13+00:00      osx     202496           TT
# 4  2025-01-01 05:25:51+00:00      osx     218013           TT
#
#   master_metadata_track_name master_metadata_album_artist_name  \
# 0                    deja vu                    Olivia Rodrigo
# 1               Crash My Car                              COIN
# 2            Everybody Talks                        Neon Trees
# 3       She Looks So Perfect               5 Seconds of Summer
# 4                Tongue Tied                         GROUPLOVE
#
#   master_metadata_album_album_name                     spotify_track_uri  \
# 0                             SOUR  spotify:track:6HU7h9RYOaPRFeh0R3UeAr
# 1                        Dreamland  spotify:track:5SN3mwuodiwY3jPejBuUD5
# 2                     Picture Show  spotify:track:2iUmqdfGZcHIhS3b9E9EWq
# 3              5 Seconds Of Summer  spotify:track:1CQ2cMfrmFM1YdfmjENKVE
# 4         Never Trust a Happy Song  spotify:track:0GO8y8jQk1PkHzS31d699N
#
#   reason_start reason_end  ...  offline_timestamp  incognito_mode  hour  \
# 0    trackdone    endplay  ...         1735679560           False     5
# 1     clickrow  trackdone  ...         1735708304           False     5
# 2    trackdone  trackdone  ...         1735708522           False     5
# 3    trackdone  trackdone  ...         1735708730           False     5
# 4    trackdone  trackdone  ...         1735708933           False     5
#
#          day    month  minutes_played  \
# 0  Wednesday  2025-01        2.640717
# 1  Wednesday  2025-01        3.138433
# 2  Wednesday  2025-01        2.954667
# 3  Wednesday  2025-01        3.374933
# 4  Wednesday  2025-01        3.633550
#
#                                  track_artist time_of_day  album_type_x  \
# 0                    deja vu - Olivia Rodrigo     Morning         Album
# 1                         Crash My Car - COIN     Morning        Single
# 2                Everybody Talks - Neon Trees     Morning        Single
# 3  She Looks So Perfect - 5 Seconds of Summer     Morning        Single
# 4                     Tongue Tied - GROUPLOVE     Morning        Single
#
#   album_type_y
# 0        Album
# 1       Single
# 2       Single
# 3       Single
# 4       Single
#
# [5 rows x 23 columns]

# %% [markdown]
# Now that we’ve explored and visualized the data, it’s time to transform the data so future insights (and predictions, if any!) are richer.
#
# **Feature engineering** is where you make the raw data work for you.
# At first, I thought that it was a scary and complex term but it's just preparing your data for predictions.
#
# There are five features we can engineer here (haha).
# 1. Time-based features - understanding when I listen and how often
# 2. User Behaviour features - quantifying how I listen
# 3. Song-level features - measuring popularity or repetition
# 4. Artist features - who do I love?
# 5. Categorical encoding (for more modeling) - one-hot encoding

# %% [markdown]
# #### Time-Based Features
# Understanding when and how often I listen to music.
# - **hour_of_day**: I typically listen to music in the late night (hr: 01, 02, 00, 23, 03)
# - **day_of_week**: I have the highest listening activity on Thursdays and the lowest on Fridays. The each day of the week has relatively similar listening times, though.
# - **month**: First, recall that this project takes data from January 1st to mid-July. June had the greatest listening time, and January, the least.

# %% [markdown]
# #### User-Behaviour Features
# Quantifying how I listen to music.
# - **session_id**: grouping plays into listening sessions (e.g. gaps >30 minutes = new session)
# - **songs_per_session**: how many tracks per session.
# - **minutes_per_session**: total lsitening time per session.

# %%
df['ts'] = pd.to_datetime(df['ts'], errors='coerce')

# %%
df['time_diff'] = df['ts'].diff().dt.total_seconds().fillna(0)
df['new_session'] = df['time_diff'] > (30 * 60)
df['session_id'] = df['new_session'].cumsum()

df.tail()
# Out:
#                              ts platform  ms_played conn_country  \
# 10915 2025-07-17 19:15:27+00:00      ios     171789           TT
# 10916 2025-07-17 19:21:40+00:00      ios     177729           TT
# 10917 2025-07-17 19:25:44+00:00      ios     173866           TT
# 10918 2025-07-17 19:32:14+00:00      ios     145454           TT
# 10919 2025-07-17 19:34:59+00:00      ios     165392           TT
#
#       master_metadata_track_name master_metadata_album_artist_name  \
# 10915                       RUSH                     Dutch Melrose
# 10916     numb (feat. blackbear)                         lilspirit
# 10917                  Sunscreen             Ax and the Hatchetmen
# 10918                      Bleed                   Connor Kauffman
# 10919              runaway bride                            Ellise
#
#       master_metadata_album_album_name                     spotify_track_uri  \
# 10915                             RUSH  spotify:track:7Ey8DZuMBbeiqMk8s8XpHA
# 10916           numb (feat. blackbear)  spotify:track:05UKPuq9D7C6YDaps38ReU
# 10917                        Sunscreen  spotify:track:7ndvAM7pJXTUOJmvypg1HX
# 10918                            Bleed  spotify:track:4k8D363TGNjILbQRciQfBD
# 10919               PRETTY EVIL DELUXE  spotify:track:0ueaaxNQtKa5m3TbTXLyIH
#
#       reason_start reason_end  ...       day    month  minutes_played  \
# 10915       fwdbtn  trackdone  ...  Thursday  2025-07        2.863150
# 10916    trackdone  trackdone  ...  Thursday  2025-07        2.962150
# 10917    trackdone  trackdone  ...  Thursday  2025-07        2.897767
# 10918    trackdone  trackdone  ...  Thursday  2025-07        2.424233
# 10919    trackdone  trackdone  ...  Thursday  2025-07        2.756533
#
#                              track_artist  time_of_day  album_type_x  \
# 10915                RUSH - Dutch Melrose      Evening        Single
# 10916  numb (feat. blackbear) - lilspirit      Evening        Single
# 10917   Sunscreen - Ax and the Hatchetmen      Evening        Single
# 10918             Bleed - Connor Kauffman      Evening        Single
# 10919              runaway bride - Ellise      Evening         Album
#
#       album_type_y time_diff  new_session session_id
# 10915       Single     197.0        False        699
# 10916       Single     373.0        False        699
# 10917       Single     244.0        False        699
# 10918       Single     390.0        False        699
# 10919        Album     165.0        False        699
#
# [5 rows x 26 columns]

# %%
songs_per_session = df.groupby('session_id')['master_metadata_track_name'].count()
songs_per_session
# Out:
# session_id
# 0       7
# 1       1
# 2       1
# 3       8
# 4       5
#        ..
# 695     8
# 696    26
# 697    14
# 698     7
# 699     7
# Name: master_metadata_track_name, Length: 700, dtype: int64

# %%
df['duration_minutes'] = df['ms_played'] / (1000 * 60)
minutes_per_session = df.groupby('session_id')['duration_minutes'].sum()
minutes_per_session
# Out:
# session_id
# 0      22.145400
# 1       1.118417
# 2       2.543250
# 3      28.535333
# 4      13.081650
#          ...
# 695    24.390983
# 696    84.550533
# 697    38.901567
# 698    17.435117
# 699    17.907383
# Name: duration_minutes, Length: 700, dtype: float64

# %% [markdown]
# #### Song-Level Features
# Measuring popularity or repetition
# - **total_plays**
# - **total_minutes**
# - **avg_duration**: total_minutes / total_plays

# %%
# Total plays and minutes played per song
song_stats = df.groupby('track_artist').agg(
    total_plays = ('master_metadata_track_name', 'count'),
    total_minutes = ('duration_minutes', 'sum')
)

song_stats['avg_duration'] = song_stats['total_minutes'] / song_stats['total_plays']
song_stats
# Out:
#                                                total_plays  total_minutes  \
# track_artist
# "Honest" - Nico Collins                                  9      28.792050
# (Baby) Come On Back - THE BAND LIGHT                     1       2.662567
# 07 Britney - Acoustic - Chelsea Collins                  1       3.079400
# 07 Britney - Chelsea Collins                             5      15.242917
# 1 step forward, 3 steps back - Olivia Rodrigo            1       2.711467
# ...                                                    ...            ...
# 夜に駆ける - YOASOBI                                          2       8.634833
# 愛して 愛して 愛して - Kikuo                                      2       8.400000
# 残響散歌 - Aimer                                             1       3.081550
# 花になって - Be a flower - Ryokuoushoku Shakai                4      14.589100
# 逆光 - ウタ from ONE PIECE FILM RED - Ado                    3      11.893100
#
#                                                avg_duration
# track_artist
# "Honest" - Nico Collins                            3.199117
# (Baby) Come On Back - THE BAND LIGHT               2.662567
# 07 Britney - Acoustic - Chelsea Collins            3.079400
# 07 Britney - Chelsea Collins                       3.048583
# 1 step forward, 3 steps back - Olivia Rodrigo      2.711467
# ...                                                     ...
# 夜に駆ける - YOASOBI                                    4.317417
# 愛して 愛して 愛して - Kikuo                                4.200000
# 残響散歌 - Aimer                                       3.081550
# 花になって - Be a flower - Ryokuoushoku Shakai          3.647275
# 逆光 - ウタ from ONE PIECE FILM RED - Ado              3.964367
#
# [1571 rows x 3 columns]

# %% [markdown]
# #### Artist Features
# Who do I love?
# - **most_played_artist**: which, as of this project, is Ellise.
# - **artist_diversity**: number of unique artist / total plays.

# %%
# Most Played Artist
artist_stats = df.groupby('master_metadata_album_artist_name').agg(
    total_plays = ('master_metadata_album_artist_name', 'count'),
    total_minutes = ('duration_minutes', 'sum')
).sort_values('total_plays', ascending=False)

artist_stats
# Out:
#                                    total_plays  total_minutes
# master_metadata_album_artist_name
# Ellise                                    1134    3100.794050
# Vlad Holiday                               784    2609.252283
# Nico & Chelsea                             502    2050.642000
# Waterparks                                 500    1477.019333
# WesGhost                                   478    1298.274417
# ...                                        ...            ...
# The Grogans                                  1       2.112150
# The Brummies                                 1       3.411333
# That Mexican OT                              1       0.512383
# Nic D                                        1       2.302250
# Tony22                                       1       1.231700
#
# [513 rows x 2 columns]

# %%
# Artist Diversity Score
unique_artists = df['master_metadata_album_artist_name'].nunique()
total_plays = len(df)
artist_diversity = (unique_artists / total_plays) * 100

print(f'Artist Diversity = ', artist_diversity, '%')
# Out:
# Artist Diversity =  4.697802197802198 %

# %% [markdown]
# #### Categorical Encoding
# - **day**: day of the week.
# - **hour**: hour of the day binned into categories.
#
# These are already in our dataframe!

# %%
df.columns
# Out:
# Index(['ts', 'platform', 'ms_played', 'conn_country',
#        'master_metadata_track_name', 'master_metadata_album_artist_name',
#        'master_metadata_album_album_name', 'spotify_track_uri', 'reason_start',
#        'reason_end', 'shuffle', 'skipped', 'offline', 'offline_timestamp',
#        'incognito_mode', 'hour', 'day', 'month', 'minutes_played',
#        'track_artist', 'time_of_day', 'album_type_x', 'album_type_y',
#        'time_diff', 'new_session', 'session_id', 'duration_minutes'],
#       dtype='object')

# %% [markdown]
# #### Bonus Features
# For funsies?

# %% [markdown]
# **Top N Flags**: boolean columns like *is_top_artist* and *is_top_song* check whether the artist or song is in the top N (let's use 10).

# %%
# Get top 10 artists and songs
top_artists = df['master_metadata_album_artist_name'].value_counts().head(10).index
top_tracks = df['master_metadata_track_name'].value_counts().head(10).index

# Create boolean columns
df['is_top_artist'] = df['master_metadata_album_artist_name'].isin(top_artists)
df['is_top_track'] = df['master_metadata_track_name'].isin(top_tracks)

# %%
df.tail()
# Out:
#                              ts platform  ms_played conn_country  \
# 10915 2025-07-17 19:15:27+00:00      ios     171789           TT
# 10916 2025-07-17 19:21:40+00:00      ios     177729           TT
# 10917 2025-07-17 19:25:44+00:00      ios     173866           TT
# 10918 2025-07-17 19:32:14+00:00      ios     145454           TT
# 10919 2025-07-17 19:34:59+00:00      ios     165392           TT
#
#       master_metadata_track_name master_metadata_album_artist_name  \
# 10915                       RUSH                     Dutch Melrose
# 10916     numb (feat. blackbear)                         lilspirit
# 10917                  Sunscreen             Ax and the Hatchetmen
# 10918                      Bleed                   Connor Kauffman
# 10919              runaway bride                            Ellise
#
#       master_metadata_album_album_name                     spotify_track_uri  \
# 10915                             RUSH  spotify:track:7Ey8DZuMBbeiqMk8s8XpHA
# 10916           numb (feat. blackbear)  spotify:track:05UKPuq9D7C6YDaps38ReU
# 10917                        Sunscreen  spotify:track:7ndvAM7pJXTUOJmvypg1HX
# 10918                            Bleed  spotify:track:4k8D363TGNjILbQRciQfBD
# 10919               PRETTY EVIL DELUXE  spotify:track:0ueaaxNQtKa5m3TbTXLyIH
#
#       reason_start reason_end  ...                        track_artist  \
# 10915       fwdbtn  trackdone  ...                RUSH - Dutch Melrose
# 10916    trackdone  trackdone  ...  numb (feat. blackbear) - lilspirit
# 10917    trackdone  trackdone  ...   Sunscreen - Ax and the Hatchetmen
# 10918    trackdone  trackdone  ...             Bleed - Connor Kauffman
# 10919    trackdone  trackdone  ...              runaway bride - Ellise
#
#        time_of_day  album_type_x  album_type_y  time_diff  new_session  \
# 10915      Evening        Single        Single      197.0        False
# 10916      Evening        Single        Single      373.0        False
# 10917      Evening        Single        Single      244.0        False
# 10918      Evening        Single        Single      390.0        False
# 10919      Evening         Album         Album      165.0        False
#
#       session_id duration_minutes  is_top_artist is_top_track
# 10915        699         2.863150          False        False
# 10916        699         2.962150          False        False
# 10917        699         2.897767          False        False
# 10918        699         2.424233          False        False
# 10919        699         2.756533           True        False
#
# [5 rows x 29 columns]

# %% [markdown]
# **Daily Listen Counts**: counts how many listens per day.

# %%
# Daily Listen Count
df['date'] = df['ts'].dt.date
daily_counts = df.groupby('date').size().reset_index(name='daily_listen_count')
df = df.merge(daily_counts, on='date')

df.head()
# Out:
#                          ts platform  ms_played conn_country  \
# 0 2025-01-01 05:11:45+00:00      osx     158443           TT
# 1 2025-01-01 05:14:52+00:00      osx     188306           TT
# 2 2025-01-01 05:18:50+00:00      osx     177280           TT
# 3 2025-01-01 05:22:13+00:00      osx     202496           TT
# 4 2025-01-01 05:25:51+00:00      osx     218013           TT
#
#   master_metadata_track_name master_metadata_album_artist_name  \
# 0                    deja vu                    Olivia Rodrigo
# 1               Crash My Car                              COIN
# 2            Everybody Talks                        Neon Trees
# 3       She Looks So Perfect               5 Seconds of Summer
# 4                Tongue Tied                         GROUPLOVE
#
#   master_metadata_album_album_name                     spotify_track_uri  \
# 0                             SOUR  spotify:track:6HU7h9RYOaPRFeh0R3UeAr
# 1                        Dreamland  spotify:track:5SN3mwuodiwY3jPejBuUD5
# 2                     Picture Show  spotify:track:2iUmqdfGZcHIhS3b9E9EWq
# 3              5 Seconds Of Summer  spotify:track:1CQ2cMfrmFM1YdfmjENKVE
# 4         Never Trust a Happy Song  spotify:track:0GO8y8jQk1PkHzS31d699N
#
#   reason_start reason_end  ...  album_type_y  time_diff  new_session  \
# 0    trackdone    endplay  ...         Album        0.0        False
# 1     clickrow  trackdone  ...        Single      187.0        False
# 2    trackdone  trackdone  ...        Single      238.0        False
# 3    trackdone  trackdone  ...        Single      203.0        False
# 4    trackdone  trackdone  ...        Single      218.0        False
#
#    session_id  duration_minutes  is_top_artist is_top_track        date  \
# 0           0          2.640717          False        False  2025-01-01
# 1           0          3.138433          False        False  2025-01-01
# 2           0          2.954667          False        False  2025-01-01
# 3           0          3.374933          False        False  2025-01-01
# 4           0          3.633550          False        False  2025-01-01
#
#    daily_listen_count_x daily_listen_count_y
# 0                    22                   22
# 1                    22                   22
# 2                    22                   22
# 3                    22                   22
# 4                    22                   22
#
# [5 rows x 32 columns]

# %% [markdown]
# **Favourite Hour Bucket**: creates a *fave_hour* feature that shows the hour of the day I most frequently listen to music.

# %%
fave_hour = df['hour'].value_counts().idxmax()
df['is_favourite_hour'] = df['hour'] == fave_hour

df.head()
# Out:
#                          ts platform  ms_played conn_country  \
# 0 2025-01-01 05:11:45+00:00      osx     158443           TT
# 1 2025-01-01 05:14:52+00:00      osx     188306           TT
# 2 2025-01-01 05:18:50+00:00      osx     177280           TT
# 3 2025-01-01 05:22:13+00:00      osx     202496           TT
# 4 2025-01-01 05:25:51+00:00      osx     218013           TT
#
#   master_metadata_track_name master_metadata_album_artist_name  \
# 0                    deja vu                    Olivia Rodrigo
# 1               Crash My Car                              COIN
# 2            Everybody Talks                        Neon Trees
# 3       She Looks So Perfect               5 Seconds of Summer
# 4                Tongue Tied                         GROUPLOVE
#
#   master_metadata_album_album_name                     spotify_track_uri  \
# 0                             SOUR  spotify:track:6HU7h9RYOaPRFeh0R3UeAr
# 1                        Dreamland  spotify:track:5SN3mwuodiwY3jPejBuUD5
# 2                     Picture Show  spotify:track:2iUmqdfGZcHIhS3b9E9EWq
# 3              5 Seconds Of Summer  spotify:track:1CQ2cMfrmFM1YdfmjENKVE
# 4         Never Trust a Happy Song  spotify:track:0GO8y8jQk1PkHzS31d699N
#
#   reason_start reason_end  ...  time_diff  new_session  session_id  \
# 0    trackdone    endplay  ...        0.0        False           0
# 1     clickrow  trackdone  ...      187.0        False           0
# 2    trackdone  trackdone  ...      238.0        False           0
# 3    trackdone  trackdone  ...      203.0        False           0
# 4    trackdone  trackdone  ...      218.0        False           0
#
#    duration_minutes  is_top_artist  is_top_track        date  \
# 0          2.640717          False         False  2025-01-01
# 1          3.138433          False         False  2025-01-01
# 2          2.954667          False         False  2025-01-01
# 3          3.374933          False         False  2025-01-01
# 4          3.633550          False         False  2025-01-01
#
#   daily_listen_count_x  daily_listen_count_y is_favourite_hour
# 0                   22                    22             False
# 1                   22                    22             False
# 2                   22                    22             False
# 3                   22                    22             False
# 4                   22                    22             False
#
# [5 rows x 33 columns]

# %%
fave_hour
# Out:
# np.int64(1)

# %% [markdown]
# **Listening Format Estimation (or Album-Style Listening)**: approximates when I'm listening to a full album straight through.

# %%
# First and foremost, data is already sorted by timestamp

# Check how often tracks from the same album are played consecutively
df['same_album_as_previous'] = (df['master_metadata_album_album_name'] == df['master_metadata_album_album_name'].shift(1)) & (df['ts'] - df['ts'].shift(1) < pd.Timedelta(minutes=10))

# Rolling album sequence
df['album_listen_block'] = df['same_album_as_previous'].cumsum()

# %% [markdown]
# **Listen Streak**: how many days in a row do I listen to music.

# %%
df['ts'] = pd.to_datetime(df['ts'])
df['date'] = df['ts'].dt.date

# Drop duplicates to avoid counting multiple listens per day
unique_dates = df[['date']].drop_duplicates().sort_values('date')

# Calculate streak
unique_dates['prev_date'] = unique_dates['date'].shift(1)
unique_dates['gap'] = unique_dates['date'] - unique_dates['prev_date']
unique_dates['new_streak'] = unique_dates['gap'].apply(lambda x: x.days > 1 if pd.notnull(x) else True)
unique_dates['streak_id'] = unique_dates['new_streak'].cumsum()

# Get streak lengths
streak_lengths = unique_dates.groupby('streak_id').size().reset_index(name='length')

# Longest streak
longest_streak = streak_lengths['length'].max()
print(f"Longest Listening Streak: {longest_streak} days")
# Out:
# Longest Listening Streak: 171 days

# %%
days_in_project = 31 + 28 + 31 + 30 + 31 + 30 + 17
print(f"The project contains data over {days_in_project} days")
# Out:
# The project contains data over 198 days

# %%
streak_score = (longest_streak / days_in_project) * 100
print(f"The longest listening streak is {streak_score}% of the length of this project")
# Out:
# The longest listening streak is 86.36363636363636% of the length of this project

# %%
# Save as csv file to load in another notebook
df.to_csv("engineered_spotify_data.csv", index=False)
